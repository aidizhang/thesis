# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# load data
train_df = pd.read_csv("../data/train.csv")
test_df = pd.read_csv("../data/test.csv")
val_df = pd.read_csv("../data/valid.csv")
# target values (which are all 0's)
y_target = np.zeros(len(test_df))

# evaluation metric: recall(k, 10)
def evaluate_recall(y, y_target, k=1):
    total = float(len(y))
    correct = 0
    for predictions, label in zip(y, y_target):
        if label in predictions[:k]:
            correct += 1
    return correct/total

# %%
test_df.head()
# Out:
#                                              Context  \
# 0  anyon know whi my stock oneir export env var u...
# 1  i set up my hd such that i have to type a pass...
# 2  im tri to use ubuntu on my macbook pro retina ...
# 3  no suggest ? __eou__ link ? __eou__ how can i ...
# 4  i just ad a second usb printer but not sure wh...
#
#                               Ground Truth Utterance  \
# 0                               nice thank ! __eou__
# 1  so you dont know , ok , anyon els ? __eou__ yo...
# 2                     just wonder how it run __eou__
# 3  you cant load anyth via usb or cd when luk be ...
# 4  i be set it up under the printer configur __eo...
#
#                                         Distractor_0  \
# 0  wrong channel for it , but check efnet.org , u...
# 1  nmap be nice , but it be n't what i be look fo...
# 2  yes , that 's what i do , export it to a `` id...
# 3  -p sorri ... __eou__ nmap -p22 __eou__ it doe ...
# ...

# %%
vectorizer = TfidfVectorizer()

# %%
traindata = np.append(train_df.Context.values, train_df.Utterance.values)

# %%
# training on this - 1mil Contexts + 1mil Utterances
traindata.shape
# Out:
# (2000000,)

# %%
vectorizer.fit(traindata)
# Out:
# TfidfVectorizer(analyzer=u'word', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), norm=u'l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern=u'(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
# after training: the vocabulary has 432654 words
vectorizer.vocabulary_
# len(vectorizer.vocabulary_)
# Out:
# {u'supergrubdisc2': 369762,
#  u'cutetv': 134741,
#  u'prinrter': 315425,
#  u'toshba': 385799,
#  u'druver': 154821,
#  u'woodi': 417743,
#  u'bfb0e4e0': 103552,
#  u'woodl': 417745,
#  u'thedash': 379258,
#  u'woodo': 417748,
#  u'825672': 64652,
#  u'woods': 417752,
#  u'woodt': 417756,
#  u'jqfmt': 228906,
#  u'prefecences': 314250,
#  u'thnkxs': 381491,
#  u'woody': 417762,
#  u'solout': 358704,
#  u'yourgroupnam': 427519,
#  u'wlapsa': 416864,
#  u'iguanacom': 212688,
#  u'kerneldriv': 232969,
#  u'p105s6117': 299076,
#  u'splashimage': 362702,
#  u'5982': 53110,
#  u'conv_': 129458,
#  u'canez': 115263,
#  u'5986': 53129,
#  u'5987': 53131,
#  u'5984': 53121,
#  u'5985': 53124,
#  u'john32': 227919,
#  u'evildnnisr': 167795,
#  u'mdraid': 262717,
#  u'rickman': 334117,
#  u'vollabel': 407013,
#  u'canel': 115254,
#  u'nuivers': 289247,
#  u'xodi': 423414,
#  u'ewook': 168116,
#  u'm1b2f4f65': 253745,
#  u'sdc10408m': 345564,
#  u'vt52a': 407771,
#  u'boncey': 107927,
# ...

# %%
# after training: the idf matrix, global term weights/idf vector
len(vectorizer.idf_)
# Out:
# 432654

# %%
from collections import defaultdict
from scipy.sparse import csr_matrix
import pandas as pd
import numpy as np
import scipy.sparse as sp
import re
from sklearn.preprocessing import normalize

# %%
class MyTfidfVectorizer:
    def __init__(self, vocabulary=None):
        self.vocabulary = vocabulary

    """
    Builds a preprocessor that converts to lowercase
    """
    def build_preprocessor(self):
        return lambda x: x.lower()
    
    """
    Returns a function that splits a string into a sequence of tokens
    """
    def build_tokenizer(self):
        token_pattern = '(?u)\\b\\w\\w+\\b'
        token_pattern = re.compile(token_pattern)
        return lambda doc: token_pattern.findall(doc)
    
    """
    Turns stop words into sequence of n-grams after stop words filtering
    """
    def word_ngrams(self, tokens, stop_words=None):
        return
    
    """
    Build analyzer for documents
    """
    def build_analyzer(self):
        preprocess = self.build_preprocessor()
        tokenize = self.build_tokenizer()
        return lambda doc: tokenize(preprocess(doc))

    """
    Count number of non-zero values for each feature in sparse X
    """
    def doc_freq(self, X):
        if sp.issparse(X):
            return np.bincount(X.indices, minlength=X.shape[1])
        else:
            return np.diff(sp.csc_matrix(X, copy=False).indptr)
    
    """
    Fit idf vectors
    """
    def fit_idf(self, X, y=None):
        if not sp.issparse(X):
            X = sp.csc_matrix(X)
        n_samples, n_features = X.shape
        df = self.doc_freq(X)
        
        # perform idf smoothing
        df += 1
        n_samples += 1
        
        # log+1 instead of log makes sure terms with zero freq don't get suppressed
        # completely
        idf = np.log(float(n_samples) / df) + 1.0
        self.idf_diag = sp.spdiags(idf, diags=0, m=n_features, n=n_features, format='csr')
    
    """
    Creates sparse feature matrix, and vocabulary if fixed_vocab is False
    """
    def count_vocab(self, rawdocs, fixed_vocab):
        if fixed_vocab:
            vocabulary = self.vocabulary
        else:
            vocabulary = defaultdict()
            vocabulary.default_factory = vocabulary.__len__
        
        analyze = self.build_analyzer()
        indices = []
        values = []
        indptr = [0]
        numdocs = 0
        for doc in rawdocs:
            numdocs += 1
            word_counter = {}
            for word in analyze(doc):
                try:
                    word_idx = vocabulary[word]
                    if word_idx not in word_counter:
                        word_counter[word_idx] = 1
                    else:
                        word_counter[word_idx] += 1
                except KeyError:
                    continue
            indices.extend(word_counter.keys())
            values.extend(word_counter.values())
            indptr.append(len(indices))
        
        if not fixed_vocab:
            # disable default dict behavior
            vocabulary = dict(vocabulary)
        
        indices = np.asarray(indices, dtype=np.intc)
        indptr = np.asarray(indptr, dtype=np.intc)
        values = np.asarray(values, dtype=np.intc)
        X = csr_matrix((values, indices, indptr), shape=(len(indptr)-1, len(vocabulary)), dtype=np.float64)
        X.sort_indices()
        return vocabulary, X

    """
    Builds vocabulary from raw documents.
    """
    def fit(self, rawdocs):
        new_vocabulary, X = self.count_vocab(rawdocs, False)
        self.vocabulary = new_vocabulary
        self.fit_idf(X) # populate self.idf_diag
        return self

    """
    Transforms into document-term matrix. Extracts token counts out of raw text
    documents using the vocabulary fitted with fit.
    """
    def transform(self, rawdocs):
        new_vocabulary, X = self.count_vocab(rawdocs, True)
        
        # sanity check
        expected_n_features = self.idf_diag.shape[0]
        assert(expected_n_features == X.shape[1])
        
        # transform count matrix to tf-idf representation
        X = X * self.idf_diag
        # normalize by row
        X = normalize(X, norm='l2', axis=1)
        return X

# %%
myvectorizer = MyTfidfVectorizer()

# %%
myvectorizer.fit(traindata)
# Out:
# <__main__.MyTfidfVectorizer instance at 0x132376f80>

# %%
myvectorizer.vocabulary;
myvectorizer.vocabulary["thank"];
myvectorizer.idf_diag[0].todense();

# %%
vector_context = vectorizer.transform([test_df.Context[0]])
vector_context
# Out:
# <1x432654 sparse matrix of type '<type 'numpy.float64'>'
# 	with 55 stored elements in Compressed Sparse Row format>

# %%
my_vector_context = myvectorizer.transform([test_df.Context[0]])
my_vector_context
# Out:
# use existing vocab
# <1x433231 sparse matrix of type '<type 'numpy.float64'>'
# 	with 55 stored elements in Compressed Sparse Row format>

# %%
vector_doc = vectorizer.transform([test_df.iloc[0,1]])
vector_doc
# Out:
# <1x432654 sparse matrix of type '<type 'numpy.float64'>'
# 	with 3 stored elements in Compressed Sparse Row format>

# %%
my_vector_doc = myvectorizer.transform(test_df.iloc[0,1:].values)
my_vector_doc
# Out:
# use existing vocab
# <10x433231 sparse matrix of type '<type 'numpy.float64'>'
# 	with 82 stored elements in Compressed Sparse Row format>

# %%
for i, elem in enumerate(np.array(vector_doc.todense())[0]):
    if elem:
        print i, elem
# Out:
# 71242 0.157444536274
# 284045 0.834491620624
# 378360 0.528048248842

# %%
for i, elem in enumerate(np.array(my_vector_doc.todense())[0]):
    if elem:
        print i, elem
# Out:
# 28 0.15744301133
# 50 0.528043134379
# 564 0.834495144635

# %%
result = np.dot(vector_doc, vector_context.T).todense()
result
# result = np.asarray(result).flatten()
# Out:
# matrix([[ 0.04612615],
#         [ 0.03412288],
#         [ 0.02754642],
#         [ 0.02031745],
#         [ 0.04340417],
#         [ 0.00275044],
#         [ 0.06837862],
#         [ 0.06378287],
#         [ 0.02580109],
#         [ 0.01074392]])

# %%
my_result = np.dot(my_vector_doc, my_vector_context.T).todense()
my_result
# my_result = np.asarray(my_result).flatten()
# Out:
# matrix([[ 0.04612448],
#         [ 0.03412241],
#         [ 0.02754574],
#         [ 0.02031658],
#         [ 0.04340342],
#         [ 0.00275036],
#         [ 0.06837662],
#         [ 0.0637812 ],
#         [ 0.02580041],
#         [ 0.01074362]])
